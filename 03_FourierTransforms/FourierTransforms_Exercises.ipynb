# %% [markdown]
# # Fourier Transforms Exercises

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import matplotlib
import math

# %matplotlib inline
matplotlib.rcParams.update({'font.size': 16,'figure.figsize':(10,6)})

# %% [markdown]
# ## Discrete Fourier Transform (DFT)
#
# $$S[m] = \sum_{n=0}^{N-1} s[n] e^{-i 2 \pi m \left({\frac{n}{N}}\right) }$$
#
# Write a function that computes the DFT of a 1D array.

# %%
def DFT_slow(s):
    """
    Compute the discrete Fourier Transform of the 1D array x
    :param s: (array)
    """
    # YOUR CODE HERE

    dft_list = []
    N = len(s)
    pi = np.pi
    euler_power = math.e
    for m in range(len(s)):
        dft = 0
        for i in range(len(s)):
            dft += s[i]*euler_power**(-complex(0,1)*2*pi*m*i/len(s))
        dft_list.append(dft)
    return dft_list

# %% [markdown]
# If you have extra time try writing a function that also computes the DFT but by using the dot product (recall the dot product sums over the element-wise products).

# %%
def DFT(s):
    """
    Compute the discrete Fourier Transform of the 1D array x
    :param s: (array)
    """

    ## YOUR CODE HERE

# %% [markdown]
# Below is an example signal constructed to test out both your DFT functions

# %%
num_sec = 5         # sampling period (in seconds)
num_pts = 500       # samples per second


# make a complex signal with two sinusoids to test both of your DFT calculation methods
t = np.linspace(0, num_sec, num_pts*num_sec)
s = np.sin(40 * 2 * np.pi * t) + 0.5 * np.sin(90 * 2 * np.pi * t)

plt.figure(figsize=(15,6))
plt.ylabel("Amplitude")
plt.xlabel("Time [s]")
plt.plot(t, s)
plt.show()

# %%
Fs = 1/(t[1] - t[0])     # sample rate
N = s.size               # number of samples (length of signal)

k = np.arange(N)         # frequncy bins
T = N/Fs                 # frequency interval of a single bin
frq = k/T                # two sides frequency range
frq = frq[range(N//2)]   # one side frequency range (Fourier transform outputs symmetric frequencies)

# %% [markdown]
# ### Perform Fourier Transform on the signal defined above using both of your DFT functions and numpy's fft
#
# Perform a DFT on the example signal created above. As a bonus, time how long it takes for each method to run and compare them! (You can use the time module, i.e. "import time".)

# %%
# Perform Fourier Transform using your function DFT() and numpy's fft

## YOUR CODE HERE

fft = np.fft.fft(s)
s_recon = np.fft.ifft(fft)
#print(DFT_slow(s))
# Out:
# [(9.322982155600587e-13+0j), (7.3914628729185576e-06-0.00588193616747687j), (2.9567768093974722e-05-0.01176461680181471j), (6.653467169308739e-05-0.017648786730526896j), (0.00011830177207443915-0.023535191509200096j), (0.00018488250515674094-0.02942457778018141j), (0.00026629418387896407-0.03531769362017505j), (0.0003625579683941828-0.04121528893614673j), (0.0004736989223145827-0.047118115815550234j), (0.000599746008076502-0.053026928885694796j), (0.0007407321110105104-0.05894248570661337j), (0.0008966940682159787-0.06486554713745567j), (0.0010676726925022612-0.0707968777087364j), (0.0012537128037077544-0.07673724601008249j), (0.0014548632617622267-0.08268742508203433j), (0.0016711769982811024-0.0886481927952868j), (0.001902711063926576-0.09462033226386252j), (0.002149526663467456-0.10060463223246414j), (0.0024116892075538607-0.10660188748981089j), (0.0026892683550416964-0.1126128992887506j), (0.0029823380739547795-0.1186384757564925j), (0.0032909766850455495-0.1246794323382876j), (0.0036152669315652575-0.13073659222477954j), (0.003955296046957816-0.13681078679772501j), (0.004311155794661849-0.14290285609465456j), (0.004682942592734564-0.14901364924359342j), (0.005070757483583955-0.1551440249915028j), (0.00547470638309542-0.16129485214422093j), (0.005894899954288149-0.16746701005841233j), (0.0063314538872529845-0.17366138920326168j), (0.006784488847597431-0.17987889161945353j), (0.007254130668510135-0.18612043149772672j), (0.007740510390405396-0.1923869357009554j), (0.008243764393740251-0.19867934433205678j), (0.008764034499941637-0.20499861133302372j), (0.009301468093029872-0.21134570505802633j), (0.009856218243191708-0.21772160889468264j), (0.010428443821650875-0.22412732189110546j), (0.011018309642647184-0.23056385940461188j), (0.011625986594973532-0.2370322537797385j), (0.012251651793043274-0.24353355502913782j), (0.012895488728807932-0.2500688315494472j), (0.013557687418194167-0.25663917085368243j), (0.014238444575702891-0.2632456803327469j), (0.014937963786293104-0.26988948804493973j), (0.015656455683241848-0.2765717435154457j), (0.0163941381292842-0.28329361858905433j), (0.01715123642385826-0.29005630828330065j), (0.01792798349895118-0.29686103170834954j), (0.018724620139007893-0.3037090329729625j), (0.01954139519042911-0.3106015821764057j), (0.02037856581633862-0.31753997638522763j), (0.021236397714400185-0.32452554069109807j), (0.02211516538680712-0.33155962927468907j), (0.02301515240117414-0.3386436265326825j), (0.023936651659795003-0.3457789482306905j), (0.024879965700535245-0.3529670427235967j), (0.025845406983420163-0.36020939219702325j), (0.026833298215126138-0.3675075139795306j), (0.027843972676530625-0.37486296190156654j), (0.0288777745570608-0.3822773277014708j), (0.029935059335705463-0.38975224250111035j), (0.03101619412424271-0.39728937834111444j), (0.0321215580828781-0.40489044977114397j), (0.033251542823306154-0.41255721552076835j), (0.03440655283215406-0.42029148023318963j), (0.03558700593158558-0.4280950962772016j), (0.036793333735024594-0.4359699656367283j), (0.03802598214514201-0.4439180418814405j), (0.03928541186808728-0.4519413322395258j), (0.040572098948121076-0.4600418997441127j), (0.041886535335641926-0.46822186548621636j), (0.04322922947526958-0.4764834109730738j), (0.04460070692245385-0.48482878059239654j), (0.046001510998955004-0.4932602841947514j), (0.04743220346745417-0.5017802997923403j), (0.048893365249382995-0.5103912763893969j), (0.050385597168233424-0.5190957369507821j), (0.05190952074695279-0.5278962815112322j), (0.053465779018142257-0.5367955904335702j), (0.055055037404701836-0.5457964278438369j), (0.05667798463160202-0.554901645202308j), (0.058335333669860594-0.5641141851037381j), (0.0600278227535642-0.5734370852187047j), (0.06175621645191033-0.5828734824945904j), (0.06352130675794525-0.5924266174953927j), (0.06532391428927073-0.6020998390555259j), (0.06716488950573087-0.6118966091149918j), (0.06904511403438002-0.6218205078363771j), (0.07096550202383875-0.6318752389950327j), (0.072927 ...

# %% [markdown]
# ## Plot the Frequency Spectrum
#
# Plot the frequency spectrum from using your DFT function(s) and numpy's fft. They should all come out the same.
#
# Note that when we plot a DFT we take the absolute value of the value returned from the fft. (The raw value returned by the fft has both real and imaginary components. When we take its absolute value we are calculating the magnitude of the sine waves that make up the original signal and ignoring their phases.) Also, we often only plot the first half of the fft. This is because when we take the fft of a completely real signal, the second half of the fft is just the complex conjugate of the first half, and thus redundant.

# %%
def plot_FT(ft, T, N, flipxy=False):
    """
    plot the Fourier Transform frequency spectrum
    :param ft: output of Fourier Transform (i.e., np.fft.fft())
    :param T: sample resolution (in seconds)
    :param N: total number of samples

    Note: only plot the first 1/2 of what the FT returns 
    (the other half is just the complex congugate)

    """
    #freq_vals = np.arange(0, (len(t)-1)/2, 1) / N #get frequency values up to nyquist frequency
    #freq_vals = np.arange(0, (len(ft))/2, 1)

    freq_vals = np.linspace(0, 1/(2*T), N//2)

    ampVals = np.abs(ft)[:N//2]
    if not flipxy:
        ## YOUR CODE HERE
       
        plt.plot(freq_vals, ampVals)
        plt.title('Fourier Transform of Original')
        plt.xlabel('Frequency (Hz)')
        plt.ylabel('|DFT(s)|')
        plt.tight_layout()

    else:
        # sometimes we may want to plot on flipped x/y axis
        ## yOUR CODE HERE
        plt.subplot(1,2,2)
        plt.plot(ampVals,freq_vals)
        plt.title('Fourier Transform of Original (Flipped)')
        plt.ylabel('Frequency (Hz)')
        plt.xlabel('|DFT(s)|')
        plt.tight_layout()

# %%
# plot using the above function you just defined and np.fft.fft to ensure they provide the same answer

T = t[1] - t[0]  # sample period
N = len(s)

## YOUR CODE HERE

plt.subplot(1,2,1)
plot_FT(fft, T, N)
plt.subplot(1,2,2)
#plot_FT(DFT_slow(s), T, N)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Inverse Fourier Transform (IFT)

# %% [markdown]
# Let's try a more complicated signal.
#
# Try taking the FFT of the ecg signal (you can use np.fft.fft) and plot it next to the time-domain signal. Can you identify any peaks in the fft corresponding to repeating structures in the ecg? (You might need to zoom into the x-axis.)
#
# Also, use the ifft function (np.fft.ifft) to reproduce the time-domain signal again from the fft and verify it matches the original.

# %%
y_ecg = np.loadtxt('https://raw.githubusercontent.com/BeaverWorksMedlytics2020/Data_Public/master/NotebookExampleData/Week2/ecg.txt',skiprows=4)



## FFT and IFFT
## YOUR CODE HERE
fft = np.fft.fft(y_ecg)
ifft = np.fft.ifft(fft)

# PLOT
## YOUR CODE HERE
x = np.linspace(1, len(fft)/2)
plt.plot(x, ifft[:len(x)])
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#fft = np.fft.fft(ifft)
T = t[1]-t[0]
N = t.size               

## PLOT FREQUENCY SPECTRUM
plot_FT(fft[1:], T,N)

# %% [markdown]
# Okay, well that looks pretty good, but how well were we able to reconstruct the signal really? Check the correlation coefficient.

# %%
#np.corrcoef(abs(y_ecg), abs(y_ecg_recon))
np.corrcoef(abs(fft), abs(ifft))
# Out:
# array([[ 1.        , -0.00100263],
#        [-0.00100263,  1.        ]])

# %% [markdown]
# ## Okay, but that was a relatively periodic signal...
# Let's try with a signal that doesn't look periodic at all!
#
# (i.e. compare the raw signal to its fft, and reconstruct the raw signal by performing an inverse Fourier transform)

# %%
import scipy.io.wavfile
from IPython.display import Audio

# original signal
(sample_rate, y_newt) = scipy.io.wavfile.read("./newt.wav")
t = np.arange(0, len(y_newt)/sample_rate, 1/sample_rate)

print('Sample rate: {} Hz'.format(sample_rate))
# Out:
# Sample rate: 11025 Hz

# %%
## PLOT FREQUENCY SPECTRUM

T = t[1]-t[0]
N = t.size               

fft = np.fft.fft(y_newt)
## YOUR CODE HERE
plot_FT(fft[1:], T,N)

# %%
# FFT, IFFT

## YOUR CODE HERE

fft = np.fft.fft(y_newt)
ifft = np.fft.ifft(fft)
# PLOT
x = np.linspace(1, len(fft)/2)
plt.plot(x, ifft[:len(x)])
## YOUR CODE HERE
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#np.corrcoef(abs(y_newt), abs(y_newt_recon))
np.corrcoef(abs(fft), abs(ifft))
# Out:
# array([[ 1.00000000e+00, -6.20051041e-04],
#        [-6.20051041e-04,  1.00000000e+00]])

# %% [markdown]
# ## Compare the original signal with the reconstructed signal by listening

# %%
# Original signal
Audio(data=y_newt, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Digitized signal
Audio(data=abs(ifft), rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1b786bcf-bec9-4934-8a64-e95efef704e0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
